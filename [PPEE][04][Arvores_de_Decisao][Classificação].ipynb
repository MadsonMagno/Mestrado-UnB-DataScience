# %% [markdown]
# # Classificação com Árvores de Decisão 🌳
#
# Neste laboratório, você será guiado para criar um modelo de Árvore de Decisão usando o dataset Iris.
# O objetivo é entender como funciona cada etapa, praticar a implementação e avaliar o desempenho do modelo.
#
# Siga as orientações abaixo, lendo atentamente cada etapa e escrevendo o seu próprio código. Boa prática!

# %% [markdown]
# ## Etapa 1: Importação de bibliotecas
#
# - Importe as bibliotecas necessárias:
#   - `pandas` e `numpy`
#   - `seaborn` e `matplotlib.pyplot`
#   - `train_test_split` de `sklearn.model_selection`
#   - `DecisionTreeClassifier` e `plot_tree` de `sklearn.tree`
#   - `classification_report`, `confusion_matrix` e `accuracy_score` de `sklearn.metrics`
#   - `LabelEncoder` de `sklearn.preprocessing`

# %%
# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização de dados
import seaborn as sns
import matplotlib.pyplot as plt

# Divisão de dados em treino e teste
from sklearn.model_selection import train_test_split

# Modelo de Árvore de Decisão
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Avaliação de desempenho
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Pré-processamento (codificar labels)
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Etapa 2: Carregamento dos dados
#
# - Carregue o dataset Iris usando o `seaborn`, `sns.load_dataset('iris')`
# - Visualize as primeiras linhas do dataset para se familiarizar com a estrutura.

# %%
#O seaborn já possui esse dataset pronto, com nomes organizados

# %% [markdown]
# ## Etapa 3: Análise inicial dos dados
#
# - Para visualizar a quantidade de cada espécie, use `sns.countplot(x='species', data=seu_dataframe)`.
# - Para criar o mapa de calor de correlação, use `sns.heatmap(seu_dataframe.corr(), annot=True)`.

# %%
#Visualização da Distribuição das Classes (Espécies)

# %%
#Correlação entre variáveis (heatmap)

# %% [markdown]
# ## Etapa 4: Verificação de dados ausentes
#
# - Verifique se existem dados faltantes no dataset.

# %%
print("\nVerificando dados ausentes:")
# Out:
# Verificando dados ausentes:

# %% [markdown]
# ## Etapa 5: Entendimento dos tipos de dados
#
# - Exiba as informações gerais do dataset (tipos de dados, quantidade de entradas não nulas, etc).

# %%
print("\nInformações do dataset:")
# Out:
# Informações do dataset:

# %% [markdown]
# ## Etapa 6: Preparação dos dados
#
# - Utilize o `LabelEncoder` para converter a coluna `species` em valores numéricos.
# - Verifique a transformação observando os valores únicos após a codificação.
#
# Obs: Crie um objeto `LabelEncoder()` e aplique o método `.fit_transform()` sobre a coluna `species`.

# %%
#O algoritmo de classificação precisa que os rótulos sejam numéricos

# %% [markdown]
# ## Etapa 7: Separação das variáveis
#
# - Separe as variáveis independentes (`X`) e a variável dependente (`y`).
#   - `X`: todas as colunas exceto `species`.
#   - `y`: apenas a coluna `species`.

# %%
#Separando os dados em
#Defina `X` usando `.drop('species', axis=1)` para remover a coluna alvo.
#Defina `y` como a coluna `species`.

# %% [markdown]
# ## Etapa 8: Divisão entre treino e teste
#
# - Divida os dados em conjuntos de treino e teste por meio do `train_test_split`:
#   - 70% para treino
#   - 30% para teste
# - Utilize um `random_state` para garantir a reprodutibilidade.

# %% [markdown]
# ## Etapa 9: Criação e treinamento do modelo
#
# - Instancie o modelo de Árvore de Decisão (`DecisionTreeClassifier`).
# - Treine o modelo utilizando os dados de treino.

# %%
#O modelo vai aprender as "regras" a partir dos dados de treino

# %% [markdown]
# ## Etapa 10: Visualização da árvore treinada
#
# - Plote a árvore de decisão treinada por meio do `plot_tree`.
# - Observe quais atributos foram mais importantes e qual a profundidade da árvore.
#
# Obs: Use `plot_tree(seu_modelo, filled=True, feature_names=X.columns, class_names=rotulos_classes)` para desenhar a árvore.

# %%
#Visualização da Árvore de Decisão - Dataset Iris

# %% [markdown]
# ## Etapa 11: Realização de previsões
#
# - Utilize o modelo treinado para fazer previsões sobre o conjunto de teste por meio do `.predict(X_test)`.

# %%
#Fazer as previsões

# %% [markdown]
# ## Etapa 12: Avaliação do desempenho
#
# - Calcule e apresente:
#   - Acurácia do modelo
#   - Matriz de confusão
#   - Relatório de classificação com precisão, recall e f1-score para cada classe

# %%
print("\n Acurácia do modelo:")
print("\n Matriz de Confusão:")
print("\n Relatório de Classificação:")
# Out:
#  Acurácia do modelo:
#
#  Matriz de Confusão:
#
#  Relatório de Classificação:
